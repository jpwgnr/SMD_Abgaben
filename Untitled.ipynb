# %% [markdown]
# # Blatt Nr.1

# %% [markdown]
# ## Aufgabe 1
#
# Es soll ein Histogramm zu den Daten aus der Datei `Groesse_Gewicht.txt` erzeugt werden und bestimmt werden, welche Unterschiede je nach Anzahl der Bins zu erkennen sind und welche Bins vernünftig erscheinen und weshalb.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
gewicht, groesse= np.genfromtxt("data.txt", unpack=True)

# %%
def subplot(x):
    a=[5, 10, 15, 20, 30, 50]
    for j,i in enumerate(a):
        plt.subplot(3,2,j+1)
        plt.hist(x, i)
        plt.tight_layout()

# %%
plt.figure(1)
subplot(gewicht)
plt.figure(2)
subplot(groesse)

# %% [markdown]
# Als Unterschiede sind dabei zu erkennen, dass die ersten beiden Plots sehr ungenau und die letzten drei Plots oftmals etwas zu detailiert wirken. Eine ziemlich gute Aussage lassen bei beiden Messungen die dritten Plots treffen.

# %% [markdown]
# ### Teil b)
#
# ...

# %% [markdown]
# ### Teil c)
# Die gleichverteilten Zahlen aus dem Bereich 1-100.

# %%
np.random.seed(100)

# %%
x = np.random.uniform(1, 100, 10000)

# %%
plt.figure(3)
subplot(x)

# %% [markdown]
# # Aufgabe 2

# %% [markdown]
# ### Teil a)
# Erzeugen von 100 Zufallszahlen aus einer Chi-Quadrat-Verteilung mit 5 Freiheitsgraden.

# %%
chi = np.random.chisquare( 5, 100)
